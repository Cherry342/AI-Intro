# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Bar Graph

# %%
bar_labels=['hollyberry', 'purevanilla', 'darkcacao']
bar_heights= [45, 36, 60]


plt.bar(bar_labels, bar_heights)
plt.show()

# %% [markdown]
# # Scatter Graph

# %%
x = [6, 7, 5, 4, ]
y = [3, 2, 8, 4]
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
